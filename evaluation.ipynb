# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/ext/daten-wi/wi20b/doduo/model/gittables_20_mosato_bert_bert-base-uncased-bs1-ml-128__gittables_30-1.00_scFalse_rs1_loss_info.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.read_csv('/ext/daten-wi/wi20b/doduo/model/gittables_20_mosato_bert_bert-base-uncased-bs1-ml-128__gittables_30-1.00_scFalse_rs1_loss_info.csv')
#
# ...

# %%
df
# Out:
#     Unnamed: 0   tr_loss  tr_f1_macro_f1  tr_f1_micro_f1   vl_loss  \
# 0            0  5.984660        0.000560        0.028220  7.118437
# 1            1  5.863474        0.000581        0.031811  6.319739
# 2            2  5.520051        0.000343        0.036429  6.732175
# 3            3  5.405869        0.000307        0.038096  6.399146
# 4            4  5.396855        0.000202        0.038610  6.643567
# 5            5  5.373221        0.000217        0.040021  6.354317
# 6            6  5.350383        0.000195        0.039507  6.791572
# 7            7  5.344297        0.000152        0.039892  6.540385
# 8            8  5.344630        0.000136        0.039636  6.541520
# 9            9  5.334494        0.000121        0.040149  6.557639
# 10          10  5.325594        0.000093        0.040021  6.620888
# 11          11  5.317633        0.000082        0.039892  6.679817
# 12          12  5.308967        0.000082        0.040021  6.690350
#
# ...

# %%
plt.plot(df['tr_loss'])
plt.plot(df['vl_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc=0)
plt.show()

# %%
plt.plot(df['tr_f1_macro_f1'])
plt.plot(df['vl_f1_macro_f1'])
plt.title('Makro F1 Score')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc=0)
plt.show()

# %%
plt.plot(df['tr_f1_micro_f1'])
plt.plot(df['vl_f1_micro_f1'])
plt.title('Mikro F1 Score')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc=0)
plt.show()
